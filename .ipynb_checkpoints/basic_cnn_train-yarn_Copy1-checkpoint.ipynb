# %%
# Importing the packages

import numpy as np 

import pandas as pd 
import os

import cv2

import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator

# %%
plt.style.use('dark_background')

# %%
# Plotting the images in the directories
def plot_imgs(directory, top=10):
    all_item_directories = os.listdir(directory)
    item_files = [os.path.join(directory, file) for file in all_item_directories][:5]
  
    plt.figure(figsize=(20, 20))
  
    for i, image_path in enumerate(item_files):
        plt.subplot(10, 10, i+1)
    
        img = plt.imread(image_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')

# %%
# calling the above function
data_path = 'C:/Users/Anu/Downloads/Group_9/dataset/dataset_eye/train'
directories = ['\Closed', '\Open']
for j in directories:
    plot_imgs(data_path+j)

# %%
# Image generator/Image preprocessing
batch_size = 128
train_datagen = ImageDataGenerator(horizontal_flip = True, 
                                  rescale = 1./255, 
                                  zoom_range = 0.2, 
                                  validation_split = 0.1)
# train_datagen = ImageDataGenerator(
#                     rescale=1./255,
#                     rotation_range=30,
#                     zoom_range = 0.2
#                     width_shift_range=0.3,
#                     height_shift_range=0.3,
#                     horizontal_flip=True,
#                     fill_mode='nearest'
#                                   )
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_data_path = 'C:/Users/Anu/Downloads/Group_9/dataset/dataset_eye/train'
test_data_path = 'C:/Users/Anu/Downloads/Group_9/dataset/dataset_eye/test'

print("Images in the train Dataset")
train_set = train_datagen.flow_from_directory(train_data_path, target_size = (256,256),
                                              batch_size = batch_size, 
                                              color_mode = 'grayscale',
                                              class_mode = 'categorical')
print("Images in the test Dataset")
test_set = test_datagen.flow_from_directory(test_data_path, target_size = (256,256),
                                              batch_size = batch_size, 
                                              color_mode = 'grayscale',
                                              class_mode = 'categorical')
# Out:
# Images in the train Dataset
# Found 1234 images belonging to 2 classes.
# Images in the test Dataset
# Found 218 images belonging to 2 classes.

# %%
# Building the model
classes = 2

model = Sequential()
model.add(Conv2D(32, (3,3), padding = 'same', input_shape = (256,256,1), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, (3,3), padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(128,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Flatten())

model.add(Dense(64, activation = 'relu'))

model.add(Dense(classes, activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8388672
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 8,481,474
# Trainable params: 8,481,474
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss = 'categorical_crossentropy',optimizer = 'adam' , metrics = ['accuracy'])
model_path="C:/Users/Anu/Downloads/Group_9/drowsiness_detection.h5"

checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, 
                              save_best_only=True, mode='max')

callbacks_list = [checkpoint]

# %%
num_epochs = 10
training_steps=train_set.n//train_set.batch_size
validation_steps =test_set.n//test_set.batch_size

# %%
print("Train\n",training_steps)
print("Test\n",validation_steps)
# Out:
# Train
#  9
# Test
#  1

# %%
print("Train images\n",train_set.n);print("batch_size\n",train_set.batch_size)
# Out:
# Train images
#  1234
# batch_size
#  128

# %%
history = model.fit_generator(train_set, epochs=num_epochs, steps_per_epoch=training_steps,validation_data=test_set,
                    validation_steps=validation_steps, callbacks = callbacks_list)
# Out:
# WARNING:tensorflow:From <ipython-input-12-02c9dc365eb9>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 9/9 [==============================] - ETA: 0s - loss: 0.7512 - accuracy: 0.5524
# Epoch 00001: val_accuracy improved from -inf to 0.81250, saving model to C:/Users/Anu/Downloads/Final_drowsiness\drowsiness_detection.h5
# 9/9 [==============================] - 94s 10s/step - loss: 0.7512 - accuracy: 0.5524 - val_loss: 0.6371 - val_accuracy: 0.8125
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 0.5343 - accuracy: 0.7613
# Epoch 00002: val_accuracy improved from 0.81250 to 0.89062, saving model to C:/Users/Anu/Downloads/Final_drowsiness\drowsiness_detection.h5
# 9/9 [==============================] - 72s 8s/step - loss: 0.5343 - accuracy: 0.7613 - val_loss: 0.2920 - val_accuracy: 0.8906
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8653
# Epoch 00003: val_accuracy improved from 0.89062 to 0.90625, saving model to C:/Users/Anu/Downloads/Final_drowsiness\drowsiness_detection.h5
# 9/9 [==============================] - 72s 8s/step - loss: 0.3200 - accuracy: 0.8653 - val_loss: 0.2432 - val_accuracy: 0.9062
# Epoch 4/10
# 9/9 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.8888
# Epoch 00004: val_accuracy did not improve from 0.90625
# 9/9 [==============================] - 68s 8s/step - loss: 0.2961 - accuracy: 0.8888 - val_loss: 0.2309 - val_accuracy: 0.8750
# Epoch 5/10
# 9/9 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9177
# Epoch 00005: val_accuracy improved from 0.90625 to 0.94531, saving model to C:/Users/Anu/Downloads/Final_drowsiness\drowsiness_detection.h5
# 9/9 [==============================] - 67s 7s/step - loss: 0.2076 - accuracy: 0.9177 - val_loss: 0.1750 - val_accuracy: 0.9453
# Epoch 6/10
# 9/9 [==============================] - ETA: 0s - loss: 0.1950 - accuracy: 0.9277
# Epoch 00006: val_accuracy did not improve from 0.94531
# 9/9 [==============================] - 69s 8s/step - loss: 0.1950 - accuracy: 0.9277 - val_loss: 0.1920 - val_accuracy: 0.9141
# Epoch 7/10
# 9/9 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9313
# Epoch 00007: val_accuracy did not improve from 0.94531
# 9/9 [==============================] - 70s 8s/step - loss: 0.1630 - accuracy: 0.9313 - val_loss: 0.2207 - val_accuracy: 0.9062
# Epoch 8/10
# 9/9 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9412
# Epoch 00008: val_accuracy improved from 0.94531 to 0.95312, saving model to C:/Users/Anu/Downloads/Final_drowsiness\drowsiness_detection.h5
# 9/9 [==============================] - 78s 9s/step - loss: 0.1420 - accuracy: 0.9412 - val_loss: 0.1523 - val_accuracy: 0.9531
# Epoch 9/10
# 9/9 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9448
# Epoch 00009: val_accuracy did not improve from 0.95312
# 9/9 [==============================] - 72s 8s/step - loss: 0.1296 - accuracy: 0.9448 - val_loss: 0.1356 - val_accuracy: 0.9531
# Epoch 10/10
# 9/9 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9503
# Epoch 00010: val_accuracy did not improve from 0.95312
# 9/9 [==============================] - 73s 8s/step - loss: 0.1217 - accuracy: 0.9503 - val_loss: 0.2012 - val_accuracy: 0.9141

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
